# %%
import pandas as pd

# %%
drink=pd.read_csv("https://bit.ly/drinksbycountry")
drink.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drink.groupby("continent").beer_servings.agg(["mean","max","min"])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93

# %%
# %matplotlib inline

# %%
drink.groupby("continent").max().plot(kind="barh")

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
pd.show_versions()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.8.3.final.0
# python-bits      : 32
# OS               : Windows
# OS-release       : 10
# machine          : AMD64
# processor        : AMD64 Family 23 Model 96 Stepping 1, AuthenticAMD
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.0.5
# numpy            : 1.18.5
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.1.1
# setuptools       : 49.2.0.post20200714
# Cython           : 0.29.21
# pytest           : 5.4.3
# hypothesis       : None
# sphinx           : 3.1.2
# ...

# %%
import numpy as np

# %%
pd.DataFrame(np.random.rand(4,9))
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.112637  0.660817  0.191746  0.174356  0.221108  0.855528  0.539377
# 1  0.797573  0.300612  0.246479  0.731353  0.543872  0.261414  0.382513
# 2  0.414686  0.621029  0.309952  0.589668  0.890935  0.364880  0.137014
# 3  0.286420  0.964537  0.364806  0.380990  0.546477  0.356625  0.191378
#
#           7         8
# 0  0.959800  0.632547
# 1  0.409744  0.343075
# 2  0.373525  0.089351
# 3  0.426583  0.082524

# %%
pd.DataFrame(np.random.rand(4,9),columns=list("abcdefghi"))
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.612438  0.002017  0.210797  0.982313  0.987860  0.277705  0.774956
# 1  0.837676  0.268983  0.413277  0.252264  0.339473  0.763410  0.175094
# 2  0.286387  0.373772  0.843136  0.868561  0.470637  0.270362  0.957567
# 3  0.088896  0.087906  0.383470  0.027588  0.796751  0.500660  0.150394
#
#           h         i
# 0  0.974312  0.679597
# 1  0.305268  0.296344
# 2  0.937832  0.468961
# 3  0.648635  0.524944

# %%
drink.loc[:,::-1]
# Out:
#          continent  total_litres_of_pure_alcohol  wine_servings  \
# 0             Asia                           0.0              0
# 1           Europe                           4.9             54
# 2           Africa                           0.7             14
# 3           Europe                          12.4            312
# 4           Africa                           5.9             45
# ..             ...                           ...            ...
# 188  South America                           7.7              3
# 189           Asia                           2.0              1
# 190           Asia                           0.1              0
# 191         Africa                           2.5              4
# 192         Africa                           4.7              4
#
#      spirit_servings  beer_servings      country
# 0                  0              0  Afghanistan
# 1                132             89      Albania
# ...

# %%
pd.read_clipboard()
# Out:
#      a   b   c
# Aj  10  32  we
# Bj  23  23  ee
# Cj  23   2  ew
